# %%
import pandas as pd
from ASECORP_BBDD import tagea_BBDD_ASECORP

# %%
list = []
df = pd.DataFrame()
ambitos = []

# %%
# Incluir ambito territorial como lista al llamar a función
# si no se especifica ámbito los incluye todos
list, df, ambitos = tagea_BBDD_ASECORP(['España','Europa'])

# %%
list
# Out:
# "['Orden ARM/795/2011', 'Resolución de 25 de marzo de 2019', 'Sentencia de 4 de mayo de 2010', 'Orden de 23 de junio de 1988', 'Real Decreto 224/2008', 'Ley 8/2020', 'Ley 16/2002', 'Reglamento (UE) 2019/2023', 'Resolución de 16 de enero de 2013', 'Resolución de 18 de diciembre de 2020', 'Real Decreto 706/2015', 'Resolución de 24 de marzo de 2015', 'Real Decreto 294/2013', 'Real Decreto 1428/2003', 'Real Decreto 1086/2015', 'Real decreto 1566/1998', 'Real Decreto 210/2003', 'Real Decreto 412/2001', 'Real Decreto 355/2013', 'Reglamento (UE) 1385/2013', 'Orden ITC/3163/2009', 'Acuerdo Multilateral M-163', 'Sentencia 192/2014', 'Resolución de 13 de mayo de 2013', 'Orden de 6 de Octubre de 1980', 'Orden de 17 de diciembre de 1984', 'Real Decreto 248/2001', 'Orden de 3 de febrero de 1986', 'Real Decreto 1466/2009', 'Real Decreto 505/2007', 'Acuerdo Multilateral M-276', 'Orden PRE/2543/2008', 'Real Decreto 1737/2010', 'Orden ECO/31/2004', 'Sentencia de 29 de junio de 2004', 'Orden Circular 
# ...

# %%
df[df['Ambito']=='Europa']
#df
# Out:
#                       Codigo     Numero  \
# 730           ANU 115/04 EUR         04
# 738        ANU 13/3/2019 EUR  13/3/2019
# 752        ANU 15/2/2018 EUR  15/2/2018
# 776      ANU 2001/205-02 EUR     205-02
# 777      ANU 2001/205-03 EUR     205-03
# ...                      ...        ...
# 16506       RES 4/3/1994 EUR   4/3/1994
# 16663       RES 5/7/2006 GAL   5/7/2006
# 16711       RES 6/2/2003 EUR   6/2/2003
# 17088  RES EMC/1615/2017 CAT       1615
# 17171   RES MAB/224/2003 CAT        224
#
#                                                   Titulo CodigoAmbito  Ambito  \
# 730    Anuncio a las empresas que tengan la intención...          EUR  Europa
# 738    Anuncio relativo a la anulación del Reglamento...          EUR  Europa
# 752    Anuncio a las empresas que tengan la intención...          EUR  Europa
# 776    Anuncio a los usuarios de la Comunidad europea...          EUR  Europa
# 777    Anuncio a los importadores de sustancias regul...          EUR  Europa
# ...

# %%
ambitos
# Out:
# ['España', 'Europa']
